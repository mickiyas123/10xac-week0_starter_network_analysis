# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import os, sys
import json
import glob

# %%
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)

from src.loader import SlackDataLoader
import src.utils as utils

# %%
# Please include the path to datafiles here for this code to work
read_file = SlackDataLoader("../anonymized")
message_with_user = read_file.slack_parser("../anonymized/Week8and9/")

# %%
mongodb_params = {
    'host': '127.0.0.1',
    'port': '27017',
    'database': 'messages',
    'collection': 'message_collection'
}

# %%
client = MongoClient(f"mongodb://{mongodb_params['host']}:{mongodb_params['port']}")

# %%
db = client[mongodb_params['database']]
collection = db[mongodb_params['collection']]

# %%
json_folder_path = '../anonymized/all-week3/'

first_json_file = None
for filename in os.listdir(json_folder_path):
    if filename.endswith('.json'):
        first_json_file = os.path.join(json_folder_path, filename)
        break

# Check if a JSON file was found
if first_json_file:
    # Read JSON data from the file
    with open(first_json_file, 'r') as file:
        json_data = json.load(file)

    # Display the JSON data
    print(f"\nJSON data from {first_json_file}:")
    print(json_data)

    # Insert JSON data into MongoDB
    collection.insert_one(json_data)

    print(f"\nData inserted into MongoDB collection '{mongodb_params['collection']}' in database '{mongodb_params['database']}' from {first_json_file}.")
else:
    print("No JSON files found in the specified folder.")

# Close the MongoDB connection
client.close()
# Out:
# JSON data from ../anonymized/all-week3/2022-09-06.json:
# [{'client_msg_id': '94e896ca-e497-4213-82a7-f34a9b31150f', 'type': 'message', 'text': 'Is there anyone who successfully connected colab with DVC on GitHub?', 'user': 'U03U9FWPNCE', 'ts': '1662448456.511829', 'blocks': [{'type': 'rich_text', 'block_id': 'WNJ', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Is there anyone who successfully connected colab with DVC on GitHub?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '2d070dcf37d6', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3991845605680_2d070dcf37d67d809af7_72.jpg', 'first_name': 'Anita', 'real_name': 'Anita Rodriguez', 'display_name': 'Anita Rodriguez', 'team': 'T03U4J8HMUG', 'name': 'Anita', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1662448456.511829', 'reply_count': 5, 'reply_users_count': 4, 'latest_reply': '1662546463.680199', 'reply_users': ['U03UH397319', 'U03U9FWPNCE', 'U03UP7V9Q57', 'U03UKL27B0R'], 'replies': [{'user': 'U03UH397319', 'ts': '1662450299.731959'}, {'user': 'U03U9FWPNCE', 'ts': '1662450428.826159'}, {'user': 'U03UP7V9Q57', 'ts': '1662475823.887129'}, {'user': 'U03U9FWPNCE', 'ts': '1662541323.243529'}, {'user': 'U03UKL27B0R', 'ts': '1662546463.680199'}], 'is_locked': False, 'subscribed': False}, {'client_msg_id': '6e821831-7071-4ce3-83d0-6ceccc5cf2d1', 'type': 'message', 'text': 'do we have to do it necessarily?', 'user': 'U03UH397319', 'ts': '1662450299.731959', 'blocks': [{'type': 'rich_text', 'block_id': '7HeJr', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'do we have to do it necessarily?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'gc7c2fbea497', 'image_72': 'https://secure.gravatar.com/avatar/c7c2fbea4976d191e3ad19004e067c11.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png', 'first_name': 'Brenda', 'real_name': 'Brenda Hernandez', 'display_name': 'Brenda Hernandez', 'team': 'T03U4J8HMUG', 'name': 'Brenda', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1662448456.511829', 'parent_user_id': 'U03U9FWPNCE'}, {'client_msg_id': '8dc51840-74c2-43a4-852a-0031ed4aa3f6', 'type': 'message', 'text': 'It was mentioned on task 2 but I am not sure.\nmaybe for the sake of  GPU!\n<@U03UP7V9Q57> and <@U03UKL27B0R> what do you think?', 'user': 'U03U9FWPNCE', 'ts': '1662450428.826159', 'blocks': [{'type': 'rich_text', 'block_id': 'Tzm', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'It was mentioned on task 2 but I am not sure.\nmaybe for the sake of  GPU!\n'}, {'type': 'user', 'user_id': 'U03UP7V9Q57'}, {'type': 'text', 'text': ' and '}, {'type': 'user', 'user_id': 'U03UKL27B0R'}, {'type': 'text', 'text': ' what do you think?'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': '2d070dcf37d6', 'image_72': 'https://avatars.slack-edge.com/2022-08-20/3991845605680_2d070dcf37d67d809af7_72.jpg', 'first_name': 'Anita', 'real_name': 'Anita Rodriguez', 'display_name': 'Anita Rodriguez', 'team': 'T03U4J8HMUG', 'name': 'Anita', 'is_restricted': False, 'is_ultra_restricted': False}, 'thread_ts': '1662448456.511829', 'parent_user_id': 'U03U9FWPNCE'}, {'client_msg_id': 'cf9c5f12-0108-4c91-828e-5d0b7583a290', 'type': 'message', 'text': "please let's join the standup here <https://meet.google.com/ysb-kjdn-hpp>", 'user': 'U03TEPYRM2P', 'ts': '1662451347.945739', 'blocks': [{'type': 'rich_text', 'block_id': 'yGjW', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "please let's join the standup here "}, {'type': 'link', 'url': 'https://meet.google.com/ysb-kjdn-hpp'}]}]}], 'team': 'T03U4J8HMUG', 'user_team': 'T03U4J8HMUG', 'source_team': 'T03U4J8HMUG', 'user_profile': {'avatar_hash': 'f113df20f89c', 'image_72': 'https://avatars.slack-edg ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 20
#      17     print(json_data)
#      19     # Insert JSON data into MongoDB
# ---> 20     collection.insert_one(json_data)
#      22     print(f"\nData inserted into MongoDB collection '{mongodb_params['collection']}' in database '{mongodb_params['database']}' from {first_json_file}.")
#      23 else:
#
# File ~/miniconda3/envs/week_0/lib/python3.10/site-packages/pymongo/collection.py:699, in Collection.insert_one(self, document, bypass_document_validation, session)
#     661 def insert_one(self, document, bypass_document_validation=False,
#     662                session=None):
#     663     """Insert a single document.
#     664
#     665       >>> db.test.count_documents({'x': 1})
#    (...)
#     697     .. versionadded:: 3.0
#     698     """
# --> 699     common.validate_is_document_type("document", document)
#     700     if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     701         document["_id"] = ObjectId()
#
# File ~/miniconda3/envs/week_0/lib/python3.10/site-packages/pymongo/common.py:503, in validate_is_document_type(option, value)
#     501 """Validate the type of method arguments that expect a MongoDB document."""
#     502 if not isinstance(value, (abc.MutableMapping, RawBSONDocument)):
# --> 503     raise TypeError("%s must be an instance of dict, bson.son.SON, "
#     504                     "bson.raw_bson.RawBSONDocument, or "
#     505                     "a type that inherits from "
#     506                     "collections.MutableMapping" % (option,))
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
